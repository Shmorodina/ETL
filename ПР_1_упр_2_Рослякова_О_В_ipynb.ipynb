# %% [markdown]
# <a href="https://colab.research.google.com/github/Shmorodina/ETL/blob/main/%D0%9F%D0%A0_1_%D1%83%D0%BF%D1%80_2_%D0%A0%D0%BE%D1%81%D0%BB%D1%8F%D0%BA%D0%BE%D0%B2%D0%B0_%D0%9E_%D0%92_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Упражнение 2** Парсинг веб-страниц с помощью Beautiful Soup и Pandas открытых источников данных

# %%
from bs4 import BeautifulSoup as bso
import pandas as pd
import re
import requests as reqs
import urllib.request
from bs4 import BeautifulSoup
import json
import os
import pprint

# %%
source = reqs.get("https://ru.investing.com/equities")

# %%
print(f"Content type: \n\t {source.headers['content-type']}")
# Out:
# Content type:
# 	 text/html; charset=utf-8

# %%
print(source)
# Out:
# <Response [200]>

# %%
mysoup = bso(source.text, 'html.parser')

# %%
print(mysoup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="html" dir="ltr" lang="ru">
#  <head>
#   <script>
#    window.geo_country_state = 'NL_GR';
#                 window.geo_country = 'NL';
#                 window.geo_state = 'GR';
#                 function appendOneTrust() {
#                     return new Promise((resolve, reject) => {
#                         const script = document.createElement('script');
#                         script.src = 'https://cookie-cdn.cookiepro.com/scripttemplates/otSDKStub.js';
#
#                         script.dataset.domainScript = '265d5ac2-7d0c-4675-bf4d-421a61fb482e';
#                         script.onload = resolve;
#                         script.onerror = reject;
#                         document.body.appendChild(script);
#                     });
#                 }
#   </script>
#   <script>
#    window.isGDPR = true;
# ...

# %%
print(mysoup.title)
# Out:
# <title>Котировки и курсы акций – Investing.com</title>
